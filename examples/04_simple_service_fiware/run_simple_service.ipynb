# %%
from dotenv import load_dotenv
from service_main.main import main
from example_service import ExampleService

# %%
loaded_env = load_dotenv(".env")
print(f"Loaded env: {loaded_env}")
# Out:
# Loaded env: True

# %%
await main(service_class=ExampleService)
# Out:
# 2025-11-07 19:41:51.489 | INFO     | encodapy.service.basic_service:prepare_basic_start:106 - Prepare the basic start of the service
# 2025-11-07 19:41:51.503 | DEBUG    | encodapy.config.models:check_timestep_units:255 - No timestep is set - using default value '1'
# 2025-11-07 19:41:51.506 | DEBUG    | encodapy.config.models:check_timestep_units:257 - No timestep unit is set - using default unit 'second'
# 2025-11-07 19:41:51.507 | DEBUG    | encodapy.config.models:check_timestep_units:259 - No sampling time is set - using default value '1'
# 2025-11-07 19:41:51.508 | DEBUG    | encodapy.config.models:check_timestep_units:261 - No sampling time unit is set - using default unit 'minute'
# 2025-11-07 19:41:51.510 | DEBUG    | encodapy.config.models:check_timestep_units:265 - No timerange type is set - using default type 'absolute'
# auth=False client_id=None client_pw=None token_url=None baerer_token=None cb_url=Url('http://localhost:1026/') service='example_service' service_path='/' crate_db_url=Url('http://localhost:4200/') crate_db_user='crate' crate_db_pw='' crate_db_ssl=False
# fiware_params=FiwareParameter(cb_url='http://localhost:1026/', service='example_service', service_path='/', authentication=None) database_params=DatabaseParameter(crate_db_url='http://localhost:4200/', crate_db_user='crate', crate_db_pw='', crate_db_ssl=False)
# 2025-11-07 19:41:51.514 | DEBUG    | encodapy.service.basic_service:_load_config:97 - ENVs succesfully loaded.
